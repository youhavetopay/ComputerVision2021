# %% [markdown]
# ### HomeWork4

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[237,265],[570,235],[566,496],[235,462]])
pts2 = np.float32([[200,200],[500,200],[500,400],[200,400]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,769))

plt.rcParams["figure.figsize"] = (20, 10)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[600,365],[599,534],[742,393],[742,540]]) # 좌상, 좌하, 우상, 우하
# pts2 = np.float32([[200,200],[200,700],[1000,200],[1000,700]]) # 이동할 위치
pts1 = np.float32([[0,212],[0,482],[1024,430],[1024,562]]) # 좌상, 좌하, 우상, 우하
pts2 = np.float32([[0,337],[0,504],[1024,337],[1024,504]]) # 이동할 위치
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,768))

plt.rcParams["figure.figsize"] = (20, 10)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[566,257],[564,332],[695,295],[700,360]]) # 좌상, 좌하, 우상, 우하
pts2 = np.float32([[0,0],[0,768],[1024,0],[1024,768]]) # 이동할 위치
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,768))

plt.rcParams["figure.figsize"] = (20, 10)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
